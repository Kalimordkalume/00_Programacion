# %%
import pandas as pd


matriz = pd.read_csv("/home/kalume/00_Programacion/Matriz.csv", sep=";")


matriz
# Out:
#     ID                            PROCESO   ID.1      PELIGRO  ID.2  \
# 0  1.0                     ADMINISTRATIVO   11.0     LOCATIVO   111
# 1  NaN                                NaN    NaN          NaN   121
# 2  2.0                          REPLANTEO   21.0  DESEGURIDAD   212
# 3  3.0   DESCARGUE Y CARGUE DE MATERIAL.    31.0  BIOMECANICO   311
# 4  4.0          ENTIVAMIENTO DE MATERIAL   431.0  BIOMECANICO  4311
# 5  5.0  TRASLADO DE ESTIVAS CON MATERIAL   531.0  BIOMECANICO   512
# 6  6.0           RECUPERACI�N DE MATERIAL  631.0  BIOMECANICO  6313
#
#                  TIPO DE RIESGO  ID.3  \
# 0       Ca�da a diferente nivel   112
# 1                  Orden y Aseo   122
# 2                     Electrico   213
# 3  Manipulaci�n Maual de Cargas   312
# 4  Manipulaci�n Maual de Cargas  4312
# 5      Desplazamiento de cargas  5313
# 6     Postura prolongada de pie  6314
#
#                                               FUENTE  ID.4  \
# ...

# %%
matriz_80 =
# Out:
# 0                       ADMINISTRATIVO
# 1                                  NaN
# 2                            REPLANTEO
# 3     DESCARGUE Y CARGUE DE MATERIAL.
# 4            ENTIVAMIENTO DE MATERIAL
# 5    TRASLADO DE ESTIVAS CON MATERIAL
# 6             RECUPERACI�N DE MATERIAL
# Name: PROCESO, dtype: object
